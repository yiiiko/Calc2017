# %%
# %matplotlib inline
from bokeh.plotting import figure, show, output_notebook
from bokeh.io import show, output_file
from bokeh.models import ColumnDataSource
from bokeh.models.tools import HoverTool
from bokeh.layouts import row,column
import numpy as np
import sympy as sy
from __future__ import print_function
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')

# %% [markdown]
# ### Intergral: Riemann Sum

# %% [markdown]
# #### Left Riemann Sum

# %%
data = {'x_values1': [0,1,2,3,4,5,6],
       'y_values1': [2,3,5,6,5,4,2],
       'x_values2': [1,2,3,4,5,6,7],
       'y_values2': [2,3,5,6,5,4,2]}

source = ColumnDataSource(data = data)

num = ['1', '2', '3', '4', '5', '6']

tools = ["hover", "reset", "box_select"]
p = figure(x_range=num, plot_height=500, title="Left Riemann Sum",
           toolbar_location=None, tools=tools)

p.vbar(x=num, top=[2, 3, 5, 6,5, 4, 2], width=0.98)
p.line(x = 'x_values1', y = 'y_values1',color='orange',source = source)
p.square(x = 'x_values1', y = 'y_values1', size = 5, color = 'orange',source = source)
p.xgrid.grid_line_color = None
p.y_range.start = 0


p1 = figure(x_range=num, plot_height=500, title="Right Riemann Sum",
           toolbar_location=None, tools=tools)

p1.vbar(x=num, top=[2, 3, 5, 6,5, 4, 2], width=0.98)
p1.line(x = 'x_values2', y = 'y_values2',color='pink',source = source)
p1.square(x = 'x_values2', y = 'y_values2', size = 5, color = 'pink',source = source)
p1.xgrid.grid_line_color = None
p1.y_range.start = 0

output_notebook()
show(row(p))
# Out:
# /Users/yikoli/anaconda/lib/python3.6/site-packages/bokeh/models/sources.py:137: BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('top', 7), ('x', 6)
#   "Current lengths: %s" % ", ".join(sorted(str((k, len(v))) for k, v in data.items())), BokehUserWarning))
# /Users/yikoli/anaconda/lib/python3.6/site-packages/bokeh/models/sources.py:137: BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('top', 7), ('x', 6)
#   "Current lengths: %s" % ", ".join(sorted(str((k, len(v))) for k, v in data.items())), BokehUserWarning))
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="99184464-1de4-4385-af04-63be953404c5">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="6eabdb14-d0fe-4a41-b184-5decefc899ba"></div>
#     </div>
# ...

# %% [markdown]
# #### Right Riemann Sum

# %%
data = {'x_values1': [0,1,2,3,4,5,6],
       'y_values1': [2,3,5,6,5,4,2],
       'x_values2': [1,2,3,4,5,6,7],
       'y_values2': [2,3,5,6,5,4,2]}

source = ColumnDataSource(data = data)

num = ['1', '2', '3', '4', '5', '6']

tools = ["hover", "reset", "box_select"]
p = figure(x_range=num, plot_height=500, title="Left Riemann Sum",
           toolbar_location=None, tools=tools)

p.vbar(x=num, top=[2, 3, 5, 6,5, 4, 2], width=0.98)
p.line(x = 'x_values1', y = 'y_values1',color='orange',source = source)
p.square(x = 'x_values1', y = 'y_values1', size = 5, color = 'orange',source = source)
p.xgrid.grid_line_color = None
p.y_range.start = 0


p1 = figure(x_range=num, plot_height=500, title="Right Riemann Sum",
           toolbar_location=None, tools=tools)

p1.vbar(x=num, top=[2, 3, 5, 6,5, 4, 2], width=0.98)
p1.line(x = 'x_values2', y = 'y_values2',color='pink',source = source)
p1.square(x = 'x_values2', y = 'y_values2', size = 5, color = 'pink',source = source)
p1.xgrid.grid_line_color = None
p1.y_range.start = 0

output_notebook()
show(row(p1))
# Out:
# /Users/yikoli/anaconda/lib/python3.6/site-packages/bokeh/models/sources.py:137: BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('top', 7), ('x', 6)
#   "Current lengths: %s" % ", ".join(sorted(str((k, len(v))) for k, v in data.items())), BokehUserWarning))
# /Users/yikoli/anaconda/lib/python3.6/site-packages/bokeh/models/sources.py:137: BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('top', 7), ('x', 6)
#   "Current lengths: %s" % ", ".join(sorted(str((k, len(v))) for k, v in data.items())), BokehUserWarning))
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="f8c14af4-19cc-4d63-89a5-c04a011e0094">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="ec7c4583-08f9-4345-b2ab-054b9c739054"></div>
#     </div>
# ...

# %%
def f(x):
    return np.e**(-x**2)
def g(x):
    return 1-np.cos(x)

x = np.linspace(0,2,20)
tools = ["hover", "reset", "box_select"]
p1 = figure(plot_width = 600, plot_height = 600, title="Left Riemann",tools=tools)


p1.line(x, f(x), line_width = 3, color = 'red')
p1.circle(x, f(x),color="green")
# p1.line(x, g(x), line_width = 3, color = 'blue')
# p1.circle(x, g(x),color="green")

p1.line([0, 0], [0,1.2], line_width=2, color = 'black')
# p1.line([0, 0], [1,0], line_width=2, color = 'black')

cr = p1.vbar(x+0.04, width = 0.1, bottom = 0, top=f(x),
              fill_color="grey", hover_fill_color="firebrick",
              fill_alpha=0.1, hover_alpha=0.3,
              line_color=None, hover_line_color="white",)

p1.add_tools(HoverTool(tooltips=None, renderers=[cr], mode='hline'))

# p1.patch([0,0,0.1,0.1], [0,1,1,0], alpha=0.5, line_width=2)

p1.y_range.start=0


output_notebook()
show(p1)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="47d543dc-4887-4bc8-80c5-c41237fdeaa3">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="8c43d642-42c7-453d-9472-c29818dd9708"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
# ...

# %%
output_file("bar_basic.html")


def f(x):
    return np.e**(-x**2)
def g(x):
    return 1-np.cos(x)

x = np.linspace(0,2,20)
tools = ["hover", "reset", "box_select"]
p2 = figure(plot_width = 600, plot_height = 600, title="Right Riemann",tools=tools)


p2.line(x, f(x), line_width = 3, color = 'blue')
p2.circle(x, f(x),color="orange")
# p1.line(x, g(x), line_width = 3, color = 'blue')
# p1.circle(x, g(x),color="green")

p2.line([0, 0], [0,1.2], line_width=2, color = 'black')
# p1.line([0, 0], [1,0], line_width=2, color = 'black')

cr = p2.vbar(x+0.04, width = 0.1, bottom = 0, top=f(x+0.1),
              fill_color="grey", hover_fill_color="blue",
              fill_alpha=0.1, hover_alpha=0.3,
              line_color=None, hover_line_color="white",)

p2.add_tools(HoverTool(tooltips=None, renderers=[cr], mode='hline'))

# p1.patch([0,0,0.1,0.1], [0,1,1,0], alpha=0.5, line_width=2)

p2.y_range.start=0


output_notebook()
show(p2)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="6e1e4255-03f9-4e8a-ae14-2849d0b93fc1">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="5aee4f65-2abe-4e15-bad6-cf94cdbc46fd"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
# ...

# %%
output_file("bar_basic.html")

def f(x):
    return np.e**(-x**2)
def g(x):
    return 1-np.cos(x)

x = np.linspace(0,2,20)
tools = ["hover", "reset", "box_select"]
p1 = figure(plot_width = 600, plot_height = 600, title="Left Riemann",tools=tools)


p1.line(x, f(x), line_width = 3, color = 'red')
p1.circle(x, f(x),color="green")
p2 = figure(plot_width = 600, plot_height = 600, title="Right Riemann",tools=tools)
p2.line(x, f(x), line_width = 3, color = 'blue')
p2.circle(x, f(x),color="orange")


p1.line([0, 0], [0,1.2], line_width=2, color = 'black')
# p1.line([0, 0], [1,0], line_width=2, color = 'black')

cr = p1.vbar(x+0.04, width = 0.1, bottom = 0, top=f(x),
              fill_color="grey", hover_fill_color="firebrick",
              fill_alpha=0.1, hover_alpha=0.3,
              line_color=None, hover_line_color="white",)

p1.add_tools(HoverTool(tooltips=None, renderers=[cr], mode='hline'))

p2.line([0, 0], [0,1.2], line_width=2, color = 'black')
# p1.line([0, 0], [1,0], line_width=2, color = 'black')

cr = p2.vbar(x+0.04, width = 0.1, bottom = 0, top=f(x+0.1),
              fill_color="grey", hover_fill_color="blue",
              fill_alpha=0.1, hover_alpha=0.3,
              line_color=None, hover_line_color="white",)

p2.add_tools(HoverTool(tooltips=None, renderers=[cr], mode='hline'))

# p1.patch([0,0,0.1,0.1], [0,1,1,0], alpha=0.5, line_width=2)

p2.y_range.start=0
p1.y_range.start=0

output_notebook()
show(column(p1,p2))
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="04f58047-9211-4ca1-9008-8a45b4c3188c">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="f446e046-1fdb-42f9-826e-4a8d68d6bf10"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
# ...

# %% [markdown]
# ### Cauchy's Definition of the Derivative

# %%
def df(a, h):
    plt.figure(figsize = (10,6), frameon=False)
    x = np.linspace(-10, 10, num=1000)
    def f(x):
        return x**2 #define the function to plot
    plt.plot(x, f(x)) #plot the parabola
    plt.plot(a, f(a), 'o', markersize = 9, color = 'black') #plot the point a, f(a)
    plt.plot(a + h, f(a+h), 'o', markersize = 9, color = 'black') #plot a point distance h from a
    slope = (f(a+h) - f(a))/(h) #compute the slope of the secant line
    plt.plot(x, slope*(x - a) + f(a)) #plot the secant line
    plt.ylim(-50, 50)
    plt.show()

interactive_plot = interactive(df, a=(-10,10,0.25), h = (0, 4, 0.1))
interactive_plot

# %% [markdown]
# #### Lotka Volterra Predator Prey Model

# %% [markdown]
# $$\frac{dx}{dt} = 0.7x - 0.3xy$$
#
# $$\frac{dy}{dt} = 0.08xy - 0.44y$$

# %%
def predator_prey(a=2,b=1,c=1,d=5):
    # Initial populations
    rabbits = [10]
    foxes = [20]

    a = a/1000.
    b = b/10000.
    c = c/10000.
    d = d/1000.
    
    dt = 0.1

    N = 20000
    for i in range(N):
        R = rabbits[-1]
        F = foxes[-1]
        change_rabbits = dt * (a*R - b*R*F)
        change_foxes = dt * (c*R*F - d*F)
        rabbits.append(rabbits[-1] + change_rabbits)
        foxes.append(foxes[-1] + change_foxes)

    plt.figure(figsize=(12,6))
    plt.plot(np.arange(N+1),rabbits)
    plt.hold(True)
    plt.plot(np.arange(N+1),foxes)
    plt.ylim(0,200); plt.xlabel('Time'); plt.ylabel('Population')
    plt.legend(('Rabbits','Foxes'),loc='best');

# %%
a = 1.
b = 0.1
c = 1.5
d = 0.75
def dX_dt(X, t=0):
    """ Return the growth rate of fox and rabbit populations. """
    return array([ a*X[0] -   b*X[0]*X[1] ,
                  -c*X[1] + d*b*X[0]*X[1] ])

# %%
from scipy import integrate
from numpy import *
t = linspace(0, 15,  1000)              # time
X0 = array([10, 5])                     # initials conditions: 10 rabbits and 5 foxes
X = integrate.odeint(dX_dt, X0, t)

# %%
rabbits, foxes = X.T
f1 = plt.figure(figsize=(12,6))
plt.plot(t, rabbits, 'r-', label='Rabbits')
plt.plot(t, foxes  , 'b-', label='Foxes')
plt.grid()
plt.legend(loc='best')
plt.xlabel('time')
plt.ylabel('population')
plt.title('Evolution of fox and rabbit populations')
f1.savefig('rabbits_and_foxes_1.png')

# %%
X_f0 = array([     0. ,  0.])
X_f1 = array([ c/(d*b), a/b])
all(dX_dt(X_f0) == zeros(2) ) and all(dX_dt(X_f1) == zeros(2))

values  = linspace(0.3, 0.9, 5)                          # position of X0 between X_f0 and X_f1
vcolors = plt.cm.autumn_r(linspace(0.3, 1., len(values)))  # colors for each trajectory

f2 = plt.figure(figsize=(12,6))

#-------------------------------------------------------
# plot trajectories
for v, col in zip(values, vcolors):
    X0 = v * X_f1                               # starting point
    X = integrate.odeint( dX_dt, X0, t)         # we don't need infodict here
    plt.plot( X[:,0], X[:,1], lw=3.5*v, color=col, label='X0=(%.f, %.f)' % ( X0[0], X0[1]) )

#-------------------------------------------------------
# define a grid and compute direction at each point
ymax = plt.ylim(ymin=0)[1]                        # get axis limits
xmax = plt.xlim(xmin=0)[1]
nb_points   = 20

x = linspace(0, xmax, nb_points)
y = linspace(0, ymax, nb_points)

X1 , Y1  = meshgrid(x, y)                       # create a grid
DX1, DY1 = dX_dt([X1, Y1])                      # compute growth rate on the gridt
M = (hypot(DX1, DY1))                           # Norm of the growth rate
M[ M == 0] = 1.                                 # Avoid zero division errors
DX1 /= M                                        # Normalize each arrows
DY1 /= M

#-------------------------------------------------------
# Drow direction fields, using matplotlib 's quiver function
# I choose to plot normalized arrows and to use colors to give information on
# the growth speed
plt.title('Trajectories and direction fields')
Q = plt.quiver(X1, Y1, DX1, DY1, M, pivot='mid', cmap=plt.cm.jet)
plt.xlabel('Number of rabbits')
plt.ylabel('Number of foxes')
plt.legend()
plt.grid()
plt.xlim(0, xmax)
plt.ylim(0, ymax)
f2.savefig('rabbits_and_foxes_2.png')
