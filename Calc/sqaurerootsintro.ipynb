# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# # My First Square Roots

# %% [markdown]
# //shift 1,2,3 for headers

# %%
2+6
# Out:
# 8

# %%
14/5
# Out:
# 2.8

# %%
4*2
# Out:
# 8

# %%
4**5
# Out:
# 1024

# %%
//** to the power
# Out:
#   File "<ipython-input-5-effa49d3a77e>", line 1
#     (/**, to, the, power)
#      ^
# SyntaxError: invalid syntax

# %%
variable = 6

# %%
variable
# Out:
# 6

# %%
variable *3
# Out:
# 18

# %%
a = 1.5

# %%
x**1345678
# Out:
# ...

# %%
x*2
# Out:
# 26

# %%
a = (1.5)

for i in range (10):
next = a(i)+2
a.append (next)
# Out:
#   File "<ipython-input-15-de166bb9fe8e>", line 4
#     next = a(i)+2
#        ^
# IndentationError: expected an indented block

# %%
a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-60b725f10c9c> in <module>()
# ----> 1 a
#
# NameError: name 'a' is not defined

# %%
a = [1.5]

for i in range (10):
    next = a [i]+2
    a.append(next)

# %%
a
# Out:
# [1.5, 3.5, 5.5, 7.5, 9.5, 11.5, 13.5, 15.5, 17.5, 19.5, 21.5]

# %%
a[0]
# Out:
# 1.5

# %%
a[0:5]
# Out:
# [1.5, 3.5, 5.5, 7.5, 9.5]

# %%
plt.plot(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-a4fc608a6a20> in <module>()
# ----> 1 plt.plot(a)
#
# NameError: name 'plt' is not defined

# %%
plt.plot(a)

# %%
plt.plot(a)

# %%
plt.plot(a,'o')
plt.title("My First Sequence ")

# %%
b =[1.5]

for i in range (40):
    next = b [i]*2
    b.append(next)

# %%
plt.plot (b, '--o'
        )

# %%
hw 08/30/3017: explore more loops
# Out:
#   File "<ipython-input-12-cc893cbe8114>", line 1
#     hw 08/30/3017: explore more loops
#         ^
# SyntaxError: invalid token

# %%
a =[3]

for i in range (7):
    next = a [i]+1
    a.append(next)

# %%
a =[3]

for i in range (7):
    next = a [i]+1
    a.append(next)

# %%
a
# Out:
# [1.5, 3.5, 5.5, 7.5, 9.5, 11.5, 13.5, 15.5, 17.5, 19.5, 21.5]

# %%
plt.plot(a,'o')
plt.title("My First Sequence ")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-deb3fff044a8> in <module>()
# ----> 1 plt.plot(a,'o')
#       2 plt.title("My First Sequence ")
#
# NameError: name 'plt' is not defined

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
a =[3]


for i in range (6):
    next = a [i]*0.5
    a.append(next)
    print (a)
# Out:
# [3, 1.5]
# [3, 1.5, 0.75]
# [3, 1.5, 0.75, 0.375]
# [3, 1.5, 0.75, 0.375, 0.1875]
# [3, 1.5, 0.75, 0.375, 0.1875, 0.09375]
# [3, 1.5, 0.75, 0.375, 0.1875, 0.09375, 0.046875]

# %%
plt.plot(a,'--o')
plt.title("0.3_1 ")

# %%
b =[0.5]


for i in range (69):
    next = b [i]+0.5**i
    b.append(next)
    
    
plt.plot(b,'--o')
plt.title("0.3_2 ")

# %%
print (b)
# Out:
# [0.5, 1.5, 2.0, 2.25, 2.375, 2.4375, 2.46875, 2.484375, 2.4921875, 2.49609375, 2.498046875, 2.4990234375, 2.49951171875, 2.499755859375, 2.4998779296875, 2.49993896484375, 2.499969482421875, 2.4999847412109375, 2.4999923706054688, 2.4999961853027344, 2.499998092651367, 2.4999990463256836, 2.499999523162842, 2.499999761581421, 2.4999998807907104, 2.4999999403953552, 2.4999999701976776, 2.499999985098839, 2.4999999925494194, 2.4999999962747097, 2.499999998137355, 2.4999999990686774, 2.4999999995343387, 2.4999999997671694, 2.4999999998835847, 2.4999999999417923, 2.499999999970896, 2.499999999985448, 2.499999999992724, 2.499999999996362, 2.499999999998181, 2.4999999999990905, 2.4999999999995453, 2.4999999999997726, 2.4999999999998863, 2.499999999999943, 2.4999999999999716, 2.499999999999986, 2.499999999999993, 2.4999999999999964, 2.4999999999999982, 2.499999999999999, 2.4999999999999996, 2.5, 2.5, 2.5, 2.5, 2.5, 2.5, 2.5, 2.5, 2.5, 2.5, 2.5, 2.5, 2.5, 2.5, 2.5, 2.5, 2.5]

# %%
x =[1.5]
a = 2**0.5

for i in range (10):
    next = 0.5*(x [i])+a/(x [i])
    x.append(next)
    
    
plt.plot(x,'--o')
plt.title("0.3_3 ")

# %%
x =[1.5]
a = 2**0.5

for i in range (10):
    next = 0.5*(x [i])+a/(x [i])
    x.append(next)
    
    
plt.plot(x,'--o')
plt.title("0.3_3a ")

# %%
x =[10]
a = 2**0.5

for i in range (10):
    next = 0.5*(x [i])+a/(x [i])
    x.append(next)
    
    
plt.plot(x,'--o')
plt.title("0.3_3b ")

# %% [markdown]
# ("0.3_3c ")
# ![FullSizeRender.jpg](attachment:FullSizeRender.jpg)
